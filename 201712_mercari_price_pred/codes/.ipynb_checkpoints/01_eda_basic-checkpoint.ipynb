# %%
import pandas as pd
import numpy as np
import codecs
from unidecode import unidecode
import re
import sys
import csv
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../inputs/train_clean.tsv', sep = '\t', encoding = 'utf-8', engine = "python")
print (len(df))
# Out:
# 1482535

# %%
df.head(5)
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Decor/Home Decor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity

# %%
# remove the rows where price is zero
df = df.loc[df['price'] > 0, :]
print (len(df))
print (df.dtypes)
print ('\nunique values\n')
for col in df.columns:
    print (col, len(df[col].unique()))
print ('\nnans\n')
for col in df.columns:
    print (col, df[col].isnull().sum())
# Out:
# 1481661
# train_id               int64
# name                  object
# item_condition_id      int64
# category_name         object
# brand_name            object
# price                float64
# shipping               int64
# item_description      object
# dtype: object
#
# unique values
#
# train_id 1481661
# name 1222951
# item_condition_id 5
# category_name 1288
# brand_name 4803
# price 827
# shipping 2
# item_description 1280441
#
# nans
#
# train_id 0
# name 11
# item_condition_id 0
# category_name 6314
# brand_name 632336
# price 0
# shipping 0
# item_description 43

# %%
# checking what the rows without any name look like
print (df.loc[df['name'].isnull(), :])
# Out:
#          train_id name  item_condition_id  \
# 208439     208439  NaN                  1
# 309630     309630  NaN                  2
# 389500     389500  NaN                  2
# 421954     421954  NaN                  1
# 695281     695281  NaN                  2
# 1012745   1012745  NaN                  2
# 1271199   1271199  NaN                  3
# 1322409   1322409  NaN                  3
# 1360970   1360970  NaN                  2
# 1427407   1427407  NaN                  2
# 1471652   1471652  NaN                  3
#
#                                       category_name       brand_name  price  \
# 208439                 Handmade/Accessories/Lanyard              NaN   24.0
# 309630                            Women/Skirts/Mini  Brandy Melville   26.0
# 389500                Women/Tops & Blouses/T-Shirts             PINK   16.0
# 421954                       Women/Jewelry/Earrings              NaN    8.0
# 695281       Women/Tops & Blouses/Button Down Shirt              NaN   27.0
# 1012745               Women/Tops & Blouses/T-Shirts              NaN    8.0
# 1271199             Women/Women's Accessories/Other             PINK    8.0
# 1322409  Women/Women's Accessories/Hair Accessories              NaN   24.0
# 1360970                           Women/Skirts/Mini  Brandy Melville   24.0
# 1427407               Women/Tops & Blouses/T-Shirts              NaN   24.0
# 1471652               Women/Tops & Blouses/T-Shirts              NaN    8.0
#
#          shipping                                   item_description
# 208439          0  Comes with 10 lanyards and two packs of hair t...
# 309630          0  *BM Raquel Skirt *Fits 24-26w *Stretchy *Side ...
# 389500          0        * Shop Alexia Danielle * ITEM| long slee...
# 421954          0  Item: Buck Logo Earribgs Brand: Browning Size ...
# 695281          1                                        Bundle deal
# 1012745         0  MEN'S COLLECTION by Alexia Danielle   ITEM* lo...
# 1271199         0   S h o p  A l e x i a  D a n i e l l e    ITEM...
# 1322409         0        * Shop Alexia Danielle * Item: 4pc 100% ...
# 1360970         0              *Perfect condition ! *FIRM #John Galt
# 1427407         0        * Shop Alexia Danielle * ITEM| t-shirt B...
# 1471652         0   SHOP ALEXIA DANIELLE   ITEM t shirt BRAND SIZ...

# %%
# checking what the rows without any item_description look like
print (df.loc[df['item_description'].isnull(), :])
# Out:
#          train_id                                      name  \
# 3552         3552                    Strappy Black Lingerie
# 119970     119970                  Bundle for Hopeismyangel
# 142890     142890                           Bow Tie Chocker
# 219766     219766             Crochet Halter Cream Crop Top
# 222500     222500                       Criss Cross Pasties
# 227220     227220                  Bundle for PandoraLover
# 275138     275138       Skirt and bodysuit bundle for kasey
# 293625     293625              FOUR 100% Activated Charcoal
# 299025     299025  Olive Green Halter Top With Back Keyhole
# 320041     320041                           Bundle For Ruby
# 323341     323341                      White Strappy Crop T
# 344824     344824                                 for buyer
# 366077     366077                       Surplice White Tank
# 371294     371294                      Pink Halter Crop Top
# 485587     485587                    Rainbow Floral Pasties
# 511535     511535                        Shoes for Michelle
# 514420     514420            One Piece Criss Cross Lingerie
# 598595     598595                              As requested
# 618452     618452                                    Ashlee
# 625528     625528                           F!ck Me Pasties
# 639935     639935                                For Selena
# 680644     680644                     Black Romper/Bodysuit
# 695383     695383                      Bundle For Bhe721 :)
# 714319     714319                   listing for bless buffs
# 861230     861230                                  Lipgloss
# 905266     905266                  Bundle for Marieasshlee
# 927229     927229                      Bundle for Maddison
# 940044     940044  Burgundy Cold Shoulder Top W/ Gold Chain
# 958821     958821                  Pink Fluff Ball Keychain
# 961177     961177     Squishy package for @squishyaesthetic
# 1061715   1061715           Hot Pink Lingerie Black Lace Up
# 1083082   1083082                Data Cable Saver Protector
# 1141348   1141348                          Strappy Tank Top
# 1174790   1174790                         Bundle for noemy
# 1224924   1224924                   Disney Minnie Head band
# 1228280   1228280                      Listing for McMillan
# 1264242   1264242                                For Bianca
# 1278794   1278794                 Grey And White Halter Top
# 1357923   1357923                     Rhinestone Body Chain
# 1391575   1391575                      Black Fishnet Tights
# 1398648   1398648                    Red Crochet Halter Top
# 1433320   1433320              Vs bling tee for summer only
# 1460887   1460887     Nude Sheer Lace Embroidered Crop Top.
#
#          item_condition_id                                      category_name  \
# 3552                     1                            Women/Underwear/Panties
# 119970                   2               Women/Athletic Apparel/Shirts & Tops
# 142890                   1                            Women/Jewelry/Necklaces
# 219766                   1                        Women/Tops & Blouses/Halter
# 222500                   1                        Women/Tops & Blouses/Halter
# 227220                   1                                  Other/Other/Other
# 275138                   1                     Women/Dresses/Above Knee, Mini
# 293625                   1           Other/Daily & Travel items/Personal Care
# 299025                   1                        Women/Tops & Blouses/Halter
# 320041                   2                      Home/Artwork/Posters & Prints
# 323341                   1                        Women/Tops & Blouses/Halter
# 344824                   2           Electronics/Video Games & Consoles/Games
# 366077                   1                    Women/Tops & Blouses/Tank, Cami
# 371294                   1                        Women/Tops & Blouses/Halter
# 485587                   1                        Women/Tops & Blouses/Halter
# 511535                   4                          Kids/Girls 0-24 Mos/Shoes
# 514420                   1                           Women/Swimwear/One-Piece
# 598595                   1                      Women/Tops & Blouses/T-Shirts
# 618452                   3                      Women/Tops & Blouses/T-Shirts
# 625528                   1                        Women/Tops & Blouses/Halter
# 639935                   2                        Women/Tops & Blouses/Blouse
# 680644                   1                     Women/Dresses/Above Knee, Mini
# 695383                   2                                  Other/Other/Other
# 714319                   1              Vintage & Collectibles/Supplies/Other
# 861230                   4                                 Beauty/Makeup/Lips
# 905266                   1                          Beauty/Makeup/Makeup Sets
# 927229                   1                          Other/Pet Supplies/Others
# 940044                   1                        Women/Tops & Blouses/Blouse
# 958821                   1                  Women/Women's Accessories/Wallets
# 961177                   2                                  Kids/Toys/Hobbies
# 1061715                  1                 Women/Underwear/G-Strings & Thongs
# 1083082                  1  Electronics/Cell Phones & Accessories/Cables &...
# 1141348                  1                    Women/Tops & Blouses/Tank, Cami
# 1174790                  1                          Other/Pet Supplies/Others
# 1224924                  3         Women/Women's Accessories/Hair Accessories
# 1228280                  2                        Kids/Girls 0-24 Mos/Dresses
# 1264242                  3          Women/Women's Accessories/Scarves & Wraps
# 1278794                  1                        Women/Tops & Blouses/Halter
# 1357923                  1                           Women/Swimwear/Two-Piece
# 1391575                  1                        Women/Tops & Blouses/Halter
# 1398648                  1                        Women/Tops & Blouses/Halter
# 1433320                  3                      Women/Tops & Blouses/T-Shirts
# 1460887                  1                    Women/Tops & Blouses/Tank, Cami
#
#                 brand_name  price  shipping item_description
# 3552                   NaN    8.0         1              NaN
# 119970                PINK   33.0         1              NaN
# 142890                 NaN    5.0         1              NaN
# 219766                 NaN   12.0         1              NaN
# 222500                 NaN    3.0         1              NaN
# 227220                 NaN   18.0         1              NaN
# 275138                 NaN   13.0         1              NaN
# 293625                 NaN   16.0         1              NaN
# 299025                 NaN   12.0         1              NaN
# 320041                 NaN   16.0         1              NaN
# 323341                 NaN   12.0         1              NaN
# 344824                 NaN    9.0         0              NaN
# 366077                 NaN   10.0         1              NaN
# 371294                 NaN   11.0         1              NaN
# 485587                 NaN    3.0         1              NaN
# 511535                 NaN    9.0         0              NaN
# 514420                 NaN   10.0         1              NaN
# 598595                Nike    9.0         1              NaN
# 618452                 NaN    9.0         1              NaN
# 625528                 NaN    5.0         1              NaN
# 639935                 NaN    7.0         1              NaN
# 680644                 NaN    7.0         1              NaN
# 695383                 NaN   20.0         0              NaN
# 714319                 NaN   64.0         1              NaN
# 861230                 NaN   49.0         0              NaN
# 905266                 NaN    6.0         1              NaN
# 927229                 NaN   10.0         0              NaN
# 940044                 NaN   10.0         1              NaN
# 958821                 NaN    5.0         1              NaN
# 961177                 NaN   39.0         1              NaN
# 1061715                NaN    8.0         1              NaN
# 1083082              Apple    6.0         1              NaN
# 1141348                NaN   12.0         1              NaN
# 1174790                NaN   12.0         0              NaN
# 1224924             Disney    9.0         0              NaN
# 1228280           Carter's   34.0         0              NaN
# 1264242                NaN   10.0         1              NaN
# 1278794                NaN   11.0         1              NaN
# 1357923                NaN    4.0         1              NaN
# 1391575                NaN    5.0         1              NaN
# 1398648                NaN   12.0         1              NaN
# 1433320  Victoria's Secret    4.0         1              NaN
# 1460887                NaN    6.0         1              NaN

# %%
# most of the item's without name/item description also have brand name empty..
# and also form a minor fraction of the dataset.. hence remove them
df = df.loc[~((df['name'].isnull()) | (df['item_description'].isnull()) | (df['category_name'].isnull())), :]
print (len(df))
# Out:
# 1476154

# %%
# overall price distribution
fig, axs = plt.subplots(nrows=2, figsize=(12,8))
sns.distplot(df['price'], ax = axs[0])
sns.distplot(np.log(df['price'] + 1), ax = axs[1])

# %%
# category names
df['num_categories'] = df['category_name'].apply(lambda x: len(str(x).split('/')))

# %%
df2 = df['category_name'].str.split('/', n=2, expand=True)
df2.columns = ['cat1', 'cat2', 'cat3']
print (len(df2))
# print (df2.columns)
print (df2.head(5))
# Out:
# 1476154
#           cat1                 cat2                cat3
# 0          Men                 Tops            T-shirts
# 1  Electronics  Computers & Tablets  Components & Parts
# 2        Women       Tops & Blouses              Blouse
# 3         Home           Home Decor  Home Decor Accents
# 4        Women              Jewelry           Necklaces

# %%
for i in range(1,4):
    df['cat' + str(i)] = df2['cat' + str(i)]
del df2

# %%
# print (df.head(5))
for i in range(1,4):
    print (len(df['cat' + str(i)].unique()))
# Out:
# 10
# 112
# 871

# %%
print (df['cat1'].unique().tolist())
# Out:
# ['Men', 'Electronics', 'Women', 'Home', 'Sports & Outdoors', 'Vintage & Collectibles', 'Beauty', 'Other', 'Kids', 'Handmade']

# %%
cat1_unique = df['cat1'].unique().tolist()
fig, axs = plt.subplots(nrows=1, figsize=(15, 10))
for i in range(5):
    filter1 = df['cat1'] == cat1_unique[i]
    # sns.distplot(df.loc[filter1, 'price'], ax = axs[i]).set_title(cat1_unique[i//2])
    sns.distplot(np.log(df.loc[filter1, 'price'] + 1), label=cat1_unique[i], hist=False)
sns.distplot(np.log(df['price'] + 1), label='overall', hist=False)
plt.legend()

# %%
fig, axs = plt.subplots(nrows=1, figsize=(15, 10))
for i in range(5, len(cat1_unique)):
    filter1 = df['cat1'] == cat1_unique[i]
    # sns.distplot(df.loc[filter1, 'price'], ax = axs[i]).set_title(cat1_unique[i//2])
    sns.distplot(np.log(df.loc[filter1, 'price'] + 1), label=cat1_unique[i], hist=False)
sns.distplot(np.log(df['price'] + 1), label='overall', hist=False)
plt.legend()

# %% [markdown]
# Price Distribution for Handmade and Electronics looks different looks very different from the overall price distribution.
